# %% [markdown]
# # Figure 5

# %%
import numpy as np
from scipy.optimize import root
from dataclasses import dataclass
import matplotlib.pyplot as plt
import import_ipynb
import GeneralMethod  # Call functions from GeneralMethod without duplicating

# %%
def I(x, y):
    if x >= 0:
        return -1 / 2 * (np.exp(-(1 / 5) * y) - np.exp(-(1 / 5) * x))
    elif y <= 0:
        return 1 / 2 * (np.exp((1 / 5) * y)-np.exp((1 / 5) * x))
    else:
        return 1 / 2 * (1 - np.exp((1 / 5) * x)) - 1 / 2 * (np.exp(-(1 / 5) * y) - 1)


params = GeneralMethod.PaymentParams(
    l_A = 100, 
    l_B = 100, 
    C = 1.0, 
    D = 2.0, 
    alpha = (2080 * (1 / 5) ** 2) / (2080 * (1 / 5) ** 2 + 0.02), 
    n = 1, 
    I = I  # The function I defined above
)

# Find the optimal cost vector
optimal_cost_vector = GeneralMethod.T_n(params)
print("Optimal cost starting at zero with l_A=100 and l_B=100:", optimal_cost_vector[int(2 * params.n * params.l_A)])
# Out:
# Optimal cost starting at zero with l_A=100 and l_B=100: 46.13104529351926

# %%
# 100 + 100 + 46.13104529351926 < 250
GeneralMethod.multi_level_search(params, 10, 250, 1, 10, unidirectional=False, symmetric=True)
# Out:
# Starting coarse search with step size: 10, l_max: 250
# l_A = 0.0, l_B = 0.0, V_n = 4160.000000001476
# l_A = 10.0, l_B = 10.0, V_n = 1020.9822137021348
# l_A = 20.0, l_B = 20.0, V_n = 547.0840084246514
# l_A = 30.0, l_B = 30.0, V_n = 385.5221167697493
# l_A = 40.0, l_B = 40.0, V_n = 304.56961016842274
# l_A = 50.0, l_B = 50.0, V_n = 260.6875062111361
# l_A = 60.0, l_B = 60.0, V_n = 238.91866032504254
# l_A = 70.0, l_B = 70.0, V_n = 230.63061495863263
# l_A = 80.0, l_B = 80.0, V_n = 230.8282265198227
# l_A = 90.0, l_B = 90.0, V_n = 236.61293105457165
# l_A = 100.0, l_B = 100.0, V_n = 246.13104529351926
# l_A = 110.0, l_B = 110.0, V_n = 258.1915212685493
# l_A = 120.0, l_B = 120.0, V_n = 272.09202155398594
# l_A = 130.0, l_B = 130.0, V_n = 287.28990706234407
# Coarse search result: l_A = 70.0, l_B = 70.0, V = 230.63061495863263
# Starting fine search with step size: 1 around the coarse minimum
# l_A = 60.0, l_B = 60.0, V_n = 238.91866032504254
# l_A = 61.0, l_B = 61.0, V_n = 237.5948053915888
# l_A = 62.0, l_B = 62.0, V_n = 236.35370962546716
# l_A = 63.0, l_B = 63.0, V_n = 235.24549339231737
# l_A = 64.0, l_B = 64.0, V_n = 234.2623642753836
# l_A = 65.0, l_B = 65.0, V_n = 233.39791242410377
# l_A = 66.0, l_B = 66.0, V_n = 232.64486428633992
# l_A = 67.0, l_B = 67.0, V_n = 231.999757212565
# l_A = 68.0, l_B = 68.0, V_n = 231.45694217711795
# l_A = 69.0, l_B = 69.0, V_n = 231.01024581180343
# l_A = 70.0, l_B = 70.0, V_n = 230.63061495863263
# l_A = 71.0, l_B = 71.0, V_n = 230.32773037208693
# l_A = 72.0, l_B = 72.0, V_n = 230.11061762232123
# l_A = 73.0, l_B = 73.0, V_n = 229.97055014117907
# l_A = 74.0, l_B = 74.0, V_n = 229.88311562004498
# l_A = 75.0, l_B = 75.0, V_n = 229.87127928256535
# l_A = 76.0, l_B = 76.0, V_n = 229.93160688990875
# l_A = 77.0, l_B = 77.0, V_n = 230.06039867520786
# l_A = 78.0, l_B = 78.0, V_n = 230.25491864933326
# l_A = 79.0, l_B = 79.0, V_n = 230.51179851685856
# l_A = 80.0, l_B = 80.0, V_n = 230.8282265198227
# (75.0, 75.0, 229.87127928256535)

# %%
params.l_A = 75 # optimal l_A 
params.l_B = 75 # optimal l_B  

optimal_cost_vector = GeneralMethod.T_n(params) # Compute the corresponding optimal cost vector

GeneralMethod.Optimal_Policy(optimal_cost_vector, 5, params, unidirectional=False)
